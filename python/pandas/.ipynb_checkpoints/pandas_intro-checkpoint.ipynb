# %%
# import numpy and pandas
import pandas as pd
import numpy as np

# %%
# Set pandas options 
# Display 30 'max_rows', no limit on 'max_columns'
# Precision is 3
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_columns', None)
pd.set_option('precision', 3)

# %%
# Assign versions of pandas/numpy to variables below
pd.version = pd.__version__
np.version = np.__version__

# %%
pd.version
# Out:
# '0.22.0'

# %%
np.version
# Out:
# '1.14.0'

# %%
# Read in 'olive.csv' using pandas and assign to 'df'
df = pd.read_csv('olive.csv')

# %%
df.head()
# Out:
#        Unnamed: 0  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
# 3  4.North-Apulia       1     1       966           57      240   7952
# 4  5.North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29
# 3       619         50         78          35
# 4       672         50         80          46

# %%
df.index
# Out:
# RangeIndex(start=0, stop=572, step=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'region', 'area', 'palmitic', 'palmitoleic', 'stearic',
#        'oleic', 'linoleic', 'linolenic', 'arachidic', 'eicosenoic'],
#       dtype='object')

# %%
len(df.index)
# Out:
# 572

# %%
# Assign the number of rows/columns in 'df' to 'df_shape'
df_shape = [len(df.index), len(df.columns)]

# %%
df_shape
# Out:
# [572, 11]

# %%
# First two rows of df
df[:2]
# Out:
#        Unnamed: 0  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29

# %%
df.head()
# Out:
#        Unnamed: 0  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
# 3  4.North-Apulia       1     1       966           57      240   7952
# 4  5.North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29
# 3       619         50         78          35
# 4       672         50         80          46

# %%
# Distinct data types in 'df'
df.dtypes.nunique()
# Out:
# 2

# %%
# Create new column 'sub_region_raw' a copy of 'Unnamed: 0'
df['sub_region_raw'] = df['Unnamed: 0']

# %%
len(df.columns)
# Out:
# 12

# %%
df.head()
# Out:
#        Unnamed: 0  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
# 3  4.North-Apulia       1     1       966           57      240   7952
# 4  5.North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic  sub_region_raw
# 0       672         36         60          29  1.North-Apulia
# 1       781         31         61          29  2.North-Apulia
# 2       549         31         63          29  3.North-Apulia
# 3       619         50         78          35  4.North-Apulia
# 4       672         50         80          46  5.North-Apulia

# %%
# Rename 'Unnamed: 0' to 'sub_region_desc'
df.rename(columns = {'Unnamed: 0': 'sub_region_desc'})
# Out:
#       sub_region_desc  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0      1.North-Apulia       1     1      1075           75      226   7823
# 1      2.North-Apulia       1     1      1088           73      224   7709
# 2      3.North-Apulia       1     1       911           54      246   8113
# 3      4.North-Apulia       1     1       966           57      240   7952
# 4      5.North-Apulia       1     1      1051           67      259   7771
# 5      6.North-Apulia       1     1       911           49      268   7924
# 6      7.North-Apulia       1     1       922           66      264   7990
# 7      8.North-Apulia       1     1      1100           61      235   7728
# 8      9.North-Apulia       1     1      1082           60      239   7745
# 9     10.North-Apulia       1     1      1037           55      213   7944
# 10    11.North-Apulia       1     1      1051           35      219   7978
# ...

# %%
# Rename column 'area' to 'sub_region'
df.rename(columns = {'area': 'sub_region'})
# Out:
#            Unnamed: 0  region  sub_region  palmitic  palmitoleic  stearic  \
# 0      1.North-Apulia       1           1      1075           75      226
# 1      2.North-Apulia       1           1      1088           73      224
# 2      3.North-Apulia       1           1       911           54      246
# 3      4.North-Apulia       1           1       966           57      240
# 4      5.North-Apulia       1           1      1051           67      259
# 5      6.North-Apulia       1           1       911           49      268
# 6      7.North-Apulia       1           1       922           66      264
# 7      8.North-Apulia       1           1      1100           61      235
# 8      9.North-Apulia       1           1      1082           60      239
# 9     10.North-Apulia       1           1      1037           55      213
# 10    11.North-Apulia       1           1      1051           35      219
# 11    12.North-Apulia       1           1      1036           59      235
# ...

# %%
# Rename column 'Unnamed: 0' to 'sub_region_desc' (Use inplace = True to make "permanent")
df.rename(columns = {'Unnamed: 0': 'sub_region_desc'}, inplace = True)

# %%
df.head()
# Out:
#   sub_region_desc  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
# 3  4.North-Apulia       1     1       966           57      240   7952
# 4  5.North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic  sub_region_raw
# 0       672         36         60          29  1.North-Apulia
# 1       781         31         61          29  2.North-Apulia
# 2       549         31         63          29  3.North-Apulia
# 3       619         50         78          35  4.North-Apulia
# 4       672         50         80          46  5.North-Apulia

# %%
# Rename column 'area' to 'sub_region' 
df.rename(columns = {'area': 'sub_region'}, inplace = True)

# %%
df.head()
# Out:
#   sub_region_desc  region  sub_region  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1           1      1075           75      226   7823
# 1  2.North-Apulia       1           1      1088           73      224   7709
# 2  3.North-Apulia       1           1       911           54      246   8113
# 3  4.North-Apulia       1           1       966           57      240   7952
# 4  5.North-Apulia       1           1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic  sub_region_raw
# 0       672         36         60          29  1.North-Apulia
# 1       781         31         61          29  2.North-Apulia
# 2       549         31         63          29  3.North-Apulia
# 3       619         50         78          35  4.North-Apulia
# 4       672         50         80          46  5.North-Apulia

# %%
# How many unique values of the field 'sub_region' are there?
df['sub_region'].nunique()
# Out:
# 9

# %%
# Get the unique values of the field 'region'
df['region'].unique()
# Out:
# array([1, 2, 3])

# %%
# Get unique values from 'sub_region_desc' after removing line numbers from each entry
df['sub_region_desc'].apply(lambda x: x[(x.find('.')+1):]).unique()
# Out:
# array(['North-Apulia', 'Calabria', 'South-Apulia', 'Sicily',
#        'Inland-Sardinia', 'Coast-Sardinia', 'Umbria', 'East-Liguria',
#        'West-Liguria'], dtype=object)
